# %%
# !pip install -r requirements.txt

# %%
import sklearn
import numpy as np
import pandas as pd

# %%
df_q1= pd.read_csv('data/ssa-report-pct-1q-2016.csv')
df_q2 = pd.read_csv('data/ssa-report-pct-2q-2016.csv')
df_q3 = pd.read_csv('data/ssa-report-pct-3q-2016.csv')
df_q4 = pd.read_csv('data/ssa-report-pct-4q-2016.csv')

# %%
df_q1
# Out:
#       Pct Intervention Type     Restraints Gender   Age                Race
# 0       1          Arrested            Yes      M  14.0      Black Hispanic
# 1       1   Juvenile Report  No Restraints      F  13.0  Asian/Pacific Isl.
# 2       1           Summons  No Restraints      M  16.0      White Hispanic
# 3       1           Summons            Yes      M  16.0               Black
# 4       1           Summons            Yes      M  16.0               Black
# ...   ...               ...            ...    ...   ...                 ...
# 1203  123   Juvenile Report  No Restraints      M  13.0      Black Hispanic
# 1204  123   Child in Crisis            Yes      F  14.0      White Hispanic
# 1205  123   Child in Crisis            Yes      F  13.0               Black
# 1206  123   Juvenile Report  No Restraints      M  14.0               Black
# 1207  123   Juvenile Report            Yes      M  14.0               Black
#
# [1208 rows x 6 columns]

# %%
df_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1208 entries, 0 to 1207
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pct                1208 non-null   int64
#  1   Intervention Type  1208 non-null   object
#  2   Restraints         1208 non-null   object
#  3   Gender             1208 non-null   object
#  4   Age                1206 non-null   float64
#  5   Race               1208 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 56.8+ KB

# %%
df_q2
# Out:
#       Pct Intervention Type     Restraints Gender  Age Greater Than 21  \
# 0       1           Summons  No Restraints      M   16              No
# 1       1           Summons  No Restraints      M   16              No
# 2       1           Summons  No Restraints      M   17              No
# 3       1           Summons  No Restraints      M   18              No
# 4       1           Summons  No Restraints      M   17              No
# ...   ...               ...            ...    ...  ...             ...
# 1086  123   Juvenile Report  No Restraints      M   13              No
# 1087  123   Juvenile Report          Metal      F   14              No
# 1088  123   Juvenile Report  No Restraints      M   15              No
# 1089  123          Arrested          Metal      M   17              No
# 1090  123           Summons  No Restraints      M   16              No
#
#                 Race
# 0              Black
# 1              Black
# 2     White Hispanic
# 3     White Hispanic
# ...

# %%
df_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1091 entries, 0 to 1090
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pct                1091 non-null   int64
#  1   Intervention Type  1091 non-null   object
#  2   Restraints         1091 non-null   object
#  3   Gender             1091 non-null   object
#  4   Age                1091 non-null   int64
#  5   Greater Than 21    1091 non-null   object
#  6   Race               1091 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 59.8+ KB

# %%
df_q3
# Out:
#      Pct Intervention Type     Restraints Gender   Age                Race
# 0      1          Arrested          Metal      M  16.0               Black
# 1      1   Child in Crisis  No Restraints      M  16.0  Asian/Pacific Isl.
# 2      1   Juvenile Report  No Restraints      F  15.0               Black
# 3      1   Juvenile Report  No Restraints      F  15.0               Black
# 4      1           Summons  No Restraints      F  16.0               Black
# ..   ...               ...            ...    ...   ...                 ...
# 730  123         Mitigated  No Restraints      M   6.0               White
# 731  123         Mitigated  No Restraints      M   6.0               White
# 732  123         Mitigated  No Restraints      M   8.0     American Indian
# 733  123           Summons          Metal      F  16.0               Black
# 734  123           Summons  No Restraints      M  16.0               White
#
# [735 rows x 6 columns]

# %%
df_q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735 entries, 0 to 734
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pct                735 non-null    int64
#  1   Intervention Type  735 non-null    object
#  2   Restraints         735 non-null    object
#  3   Gender             735 non-null    object
#  4   Age                733 non-null    float64
#  5   Race               735 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 34.6+ KB

# %%
df_q4
# Out:
#       Pct Intervention Type     Restraints Gender   Age   Race  Unnamed: 6  \
# 0       1          Arrested          Metal      F  17.0  Black         NaN
# 1       1          Arrested          Metal      M  18.0  Black         NaN
# 2       1          Arrested          Metal      M  16.0  Black         NaN
# 3       1          Arrested          Metal      M  14.0  Black         NaN
# 4       1          Arrested  No Restraints      M  18.0  Black         NaN
# ...   ...               ...            ...    ...   ...    ...         ...
# 2922  123    PINS / Warrant          Metal      M  15.0  Black         NaN
# 2923  123           Summons          Metal      M  18.0  Black         NaN
# 2924  123           Summons  No Restraints      F  44.0  White         NaN
# 2925  123           Summons  No Restraints      F  33.0  White         NaN
# 2926  123           Summons  No Restraints      F  38.0  White         NaN
#
#      Unnamed: 7
# 0           NaN
# 1           NaN
# ...

# %%
del df_q4["Unnamed: 6"]
del df_q4["Unnamed: 7"]

# %%
df_q4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2927 entries, 0 to 2926
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pct                2927 non-null   int64
#  1   Intervention Type  2927 non-null   object
#  2   Restraints         2927 non-null   object
#  3   Gender             2927 non-null   object
#  4   Age                2910 non-null   float64
#  5   Race               2927 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 137.3+ KB

# %%
df_first_half = pd.concat([df_q1, df_q2])

# %%
df_first_half
# Out:
#       Pct Intervention Type     Restraints Gender   Age                Race  \
# 0       1          Arrested            Yes      M  14.0      Black Hispanic
# 1       1   Juvenile Report  No Restraints      F  13.0  Asian/Pacific Isl.
# 2       1           Summons  No Restraints      M  16.0      White Hispanic
# 3       1           Summons            Yes      M  16.0               Black
# 4       1           Summons            Yes      M  16.0               Black
# ...   ...               ...            ...    ...   ...                 ...
# 1086  123   Juvenile Report  No Restraints      M  13.0               Black
# 1087  123   Juvenile Report          Metal      F  14.0               Black
# 1088  123   Juvenile Report  No Restraints      M  15.0               White
# 1089  123          Arrested          Metal      M  17.0               Black
# 1090  123           Summons  No Restraints      M  16.0      Black Hispanic
#
#      Greater Than 21
# 0                NaN
# ...

# %%
df_second_half = pd.concat([df_q3, df_q4])

# %%
df_second_half
# Out:
#       Pct Intervention Type     Restraints Gender   Age                Race
# 0       1          Arrested          Metal      M  16.0               Black
# 1       1   Child in Crisis  No Restraints      M  16.0  Asian/Pacific Isl.
# 2       1   Juvenile Report  No Restraints      F  15.0               Black
# 3       1   Juvenile Report  No Restraints      F  15.0               Black
# 4       1           Summons  No Restraints      F  16.0               Black
# ...   ...               ...            ...    ...   ...                 ...
# 2922  123    PINS / Warrant          Metal      M  15.0               Black
# 2923  123           Summons          Metal      M  18.0               Black
# 2924  123           Summons  No Restraints      F  44.0               White
# 2925  123           Summons  No Restraints      F  33.0               White
# 2926  123           Summons  No Restraints      F  38.0               White
#
# [3662 rows x 6 columns]

# %%
SSA_2016_PCT_df = pd.concat([df_first_half, df_second_half])

# %%
SSA_2016_PCT_df
# Out:
#       Pct Intervention Type     Restraints Gender   Age                Race  \
# 0       1          Arrested            Yes      M  14.0      Black Hispanic
# 1       1   Juvenile Report  No Restraints      F  13.0  Asian/Pacific Isl.
# 2       1           Summons  No Restraints      M  16.0      White Hispanic
# 3       1           Summons            Yes      M  16.0               Black
# 4       1           Summons            Yes      M  16.0               Black
# ...   ...               ...            ...    ...   ...                 ...
# 2922  123    PINS / Warrant          Metal      M  15.0               Black
# 2923  123           Summons          Metal      M  18.0               Black
# 2924  123           Summons  No Restraints      F  44.0               White
# 2925  123           Summons  No Restraints      F  33.0               White
# 2926  123           Summons  No Restraints      F  38.0               White
#
#      Greater Than 21
# 0                NaN
# ...

# %%
SSA_2016_PCT_df = SSA_2016_PCT_df.drop(['Greater Than 21'], axis = 1)

# %%
SSA_2016_PCT_df
# Out:
#       Pct Intervention Type     Restraints Gender   Age                Race
# 0       1          Arrested            Yes      M  14.0      Black Hispanic
# 1       1   Juvenile Report  No Restraints      F  13.0  Asian/Pacific Isl.
# 2       1           Summons  No Restraints      M  16.0      White Hispanic
# 3       1           Summons            Yes      M  16.0               Black
# 4       1           Summons            Yes      M  16.0               Black
# ...   ...               ...            ...    ...   ...                 ...
# 2922  123    PINS / Warrant          Metal      M  15.0               Black
# 2923  123           Summons          Metal      M  18.0               Black
# 2924  123           Summons  No Restraints      F  44.0               White
# 2925  123           Summons  No Restraints      F  33.0               White
# 2926  123           Summons  No Restraints      F  38.0               White
#
# [5961 rows x 6 columns]

# %%
SSA_2016_PCT_df.to_csv('data/clean_SSA_2016_PCT.csv', encoding='utf-8')
