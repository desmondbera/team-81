# %%
# !pip install -r requirements.txt

# %%
import sklearn
import numpy as np
import pandas as pd

# %%
df_q1= pd.read_csv('data/ssa-report-school-1q-2016.csv')
df_q2 = pd.read_csv('data/ssa-report-school-2q-2016.csv')
df_q3 = pd.read_csv('data/ssa-report-school-3q-2016.csv')
df_q4 = pd.read_csv('data/ssa-report-school-4q-2016.csv')

# %%
df_q1
# Out:
#                                   School Campus Intervention Type  \
# 0                        Abraham Lincoln HS(BS)          Arrested
# 1                        Abraham Lincoln HS(BS)          Arrested
# 2                        Abraham Lincoln HS(BS)          Arrested
# 3                        Abraham Lincoln HS(BS)   Child in Crisis
# 4                        Abraham Lincoln HS(BS)          Arrested
# ...                                         ...               ...
# 1203                       WINGS ACADEMY(Bronx)           Summons
# 1204                       WINGS ACADEMY(Bronx)           Summons
# 1205  YALA MANHATTAN LEARNING CENTER(Manhattan)           Summons
# 1206  YALA MANHATTAN LEARNING CENTER(Manhattan)          Arrested
# 1207  YALA MANHATTAN LEARNING CENTER(Manhattan)          Arrested
#
#      Scanning Type School Related School Hours Enforcement By     Restraints  \
# 0        Full-Time              Y            Y         PATROL            Yes
# ...

# %%
df_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1208 entries, 0 to 1207
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      1208 non-null   object
#  1   Intervention Type  1208 non-null   object
#  2   Scanning Type      1208 non-null   object
#  3   School Related     1208 non-null   object
#  4   School Hours       1208 non-null   object
#  5   Enforcment By      1123 non-null   object
#  6   Restraints         1208 non-null   object
#  7   Force              1119 non-null   object
#  8   Top Charge         436 non-null    object
#  9   SummonsCharge      339 non-null    object
#  10  Classification     955 non-null    object
#  11  Incident Location  1132 non-null   object
#  12  Scanning Incident  1125 non-null   object
# dtypes: object(13)
# memory usage: 122.8+ KB

# %%
df_q1 = df_q1.rename(columns = {"Class":"Classification"})

# %%
df_q1 = df_q1.rename(columns = {" Arrest Top Charge":"Arrest Top Charge"})
df_q1 = df_q1.rename(columns = {"School Rel":"School Related"})
df_q1 = df_q1.rename(columns = {"Summons Charge":"SummonsCharge"})
df_q1 = df_q1.rename(columns = {"Enforcement By":"Enforcment By"})
df_q1 = df_q1.rename(columns = {"Arrest Top Charge":"Top Charge"})

# %%
df_q2
# Out:
#                                        School Campus Intervention Type  \
# 0                             Abraham Lincoln HS(BS)          Arrested
# 1                             Abraham Lincoln HS(BS)          Arrested
# 2                             Abraham Lincoln HS(BS)          Arrested
# 3                             Abraham Lincoln HS(BS)   Juvenile Report
# 4     Academy for Careers in Television and Film(QN)   Child in Crisis
# ...                                              ...               ...
# 1086       Young Women Leadership School of Brooklyn           Summons
# 1087       Young Women Leadership School of Brooklyn           Summons
# 1088       Young Women Leadership School of Brooklyn           Summons
# 1089       Young Women Leadership School of Brooklyn           Summons
# 1090       Young Women Leadership School of Brooklyn           Summons
#
#      Greater Than 21 Scanning Type School Related School Hours Command  \
# ...

# %%
df_q2 = df_q2.rename(columns = {"Summons Charge":"SummonsCharge"})
df_q2 = df_q2.rename(columns = {"Command":"Enforcment By"})
df_q2 = df_q2.rename(columns = {"Type of Force Used":"Type Of Force"})
df_q2 = df_q2.rename(columns = {"Arrest Top Charge":"Top Charge"})

# %%
df_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1091 entries, 0 to 1090
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      1091 non-null   object
#  1   Intervention Type  1091 non-null   object
#  2   Greater Than 21    1091 non-null   object
#  3   Scanning Type      1091 non-null   object
#  4   School Related     1091 non-null   object
#  5   School Hours       1091 non-null   object
#  6   Enforcment By      1088 non-null   object
#  7   Restraints         1091 non-null   object
#  8   Force              1091 non-null   object
#  9   Type Of Force      1091 non-null   object
#  10  Top Charge         439 non-null    object
#  11  SummonsCharge      259 non-null    object
#  12  Classification     938 non-null    object
#  13  Incident Location  1091 non-null   object
#  14  Scanning Incident  1091 non-null   object
# dtypes: object(15)
# memory usage: 128.0+ KB

# %%
df_q3
# Out:
#                                          School Campus Intervention Type  \
# 0             Academy for Environmental Leadership(BN)           Summons
# 1                       ACADEMY OF URBAN PLANNING(BN)     PINS / Warrant
# 2    Achievement First North Brooklyn Prep Charter ...   Child in Crisis
# 3                      Alfred E. Smith Campus YABC(XW)   Child in Crisis
# 4                      Alfred E. Smith Campus YABC(XW)    PINS / Warrant
# ..                                                 ...               ...
# 730                 WILLIAM H. TAFT HIGH SCHOOL(Bronx)         Mitigated
# 731                 WILLIAM H. TAFT HIGH SCHOOL(Bronx)         Mitigated
# 732         WILLIAMSBURG PREPARATORY SCHOOL(Brooklyn)    Child in Crisis
# 733                               WINGS ACADEMY(Bronx)          Arrested
# 734                               WINGS ACADEMY(Bronx)    PINS / Warrant
#
#     Greater than 21 Scanning Type School Related School Hours  Command  \
# ...

# %%
df_q3 = df_q3.rename(columns = {"Summons Charge":"SummonsCharge"})

# %%
df_q3 = df_q3.rename(columns = {"Greater than 21":"Greater Than 21"})
df_q3 = df_q3.rename(columns = {"Type of Force Used":"Type Of Force"})
df_q3 = df_q3.rename(columns = {"Command":"Enforcment By"})

# %%
df_q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735 entries, 0 to 734
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      735 non-null    object
#  1   Intervention Type  735 non-null    object
#  2   Greater Than 21    735 non-null    object
#  3   Scanning Type      735 non-null    object
#  4   School Related     735 non-null    object
#  5   School Hours       735 non-null    object
#  6   Enforcment By      585 non-null    object
#  7   Restraints         735 non-null    object
#  8   Force              735 non-null    object
#  9   Type Of Force      735 non-null    object
#  10  Top Charge         140 non-null    object
#  11  SummonsCharge      86 non-null     object
#  12  Classification     299 non-null    object
#  13  Incident Location  735 non-null    object
#  14  Scanning Incident  735 non-null    object
# dtypes: object(15)
# memory usage: 86.3+ KB

# %%
df_q4
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Juvenile Report
# 1     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...         Mitigated
# 2                                Abraham Lincoln HS(BS)          Arrested
# 3                                Abraham Lincoln HS(BS)          Arrested
# 4                                Abraham Lincoln HS(BS)   Child in Crisis
# ...                                                 ...               ...
# 2922                               WINGS ACADEMY(Bronx)         Mitigated
# 2923                               WINGS ACADEMY(Bronx)         Mitigated
# 2924                               WINGS ACADEMY(Bronx)         Mitigated
# 2925  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Juvenile Report
# 2926  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2927 entries, 0 to 2926
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      2927 non-null   object
#  1   Intervention Type  2927 non-null   object
#  2   Incident Location  2927 non-null   object
#  3   Greater Than 21    2927 non-null   object
#  4   Scanning Type      2927 non-null   object
#  5   Scanning Incident  2927 non-null   object
#  6   School Related     2927 non-null   object
#  7   School Hours       2927 non-null   object
#  8   Enforcment By      2273 non-null   object
#  9   Restraints         2927 non-null   object
#  10  Force              2795 non-null   object
#  11  Type Of Force      2795 non-null   object
#  12  Top Charge         373 non-null    object
#  13  SummonsCharge      254 non-null    object
#  14  Classification     891 non-null    object
# dtypes: object(15)
# memory usage: 343.1+ KB

# %%
df_first_half = pd.concat([df_q1, df_q2])

# %%
df_first_half
# Out:
#                                   School Campus Intervention Type  \
# 0                        Abraham Lincoln HS(BS)          Arrested
# 1                        Abraham Lincoln HS(BS)          Arrested
# 2                        Abraham Lincoln HS(BS)          Arrested
# 3                        Abraham Lincoln HS(BS)   Child in Crisis
# 4                        Abraham Lincoln HS(BS)          Arrested
# ...                                         ...               ...
# 1086  Young Women Leadership School of Brooklyn           Summons
# 1087  Young Women Leadership School of Brooklyn           Summons
# 1088  Young Women Leadership School of Brooklyn           Summons
# 1089  Young Women Leadership School of Brooklyn           Summons
# 1090  Young Women Leadership School of Brooklyn           Summons
#
#      Scanning Type School Related School Hours Enforcment By     Restraints  \
# 0        Full-Time              Y            Y        PATROL            Yes
# ...

# %%
df_second_half = pd.concat([df_q3, df_q4])

# %%
df_second_half
# Out:
#                                           School Campus Intervention Type  \
# 0              Academy for Environmental Leadership(BN)           Summons
# 1                        ACADEMY OF URBAN PLANNING(BN)     PINS / Warrant
# 2     Achievement First North Brooklyn Prep Charter ...   Child in Crisis
# 3                       Alfred E. Smith Campus YABC(XW)   Child in Crisis
# 4                       Alfred E. Smith Campus YABC(XW)    PINS / Warrant
# ...                                                 ...               ...
# 2922                               WINGS ACADEMY(Bronx)         Mitigated
# 2923                               WINGS ACADEMY(Bronx)         Mitigated
# 2924                               WINGS ACADEMY(Bronx)         Mitigated
# 2925  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Juvenile Report
# 2926  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
#
#      Greater Than 21 Scanning Type School Related School Hours Enforcment By  \
# ...

# %%
df_second_half.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3662 entries, 0 to 2926
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3662 non-null   object
#  1   Intervention Type  3662 non-null   object
#  2   Greater Than 21    3662 non-null   object
#  3   Scanning Type      3662 non-null   object
#  4   School Related     3662 non-null   object
#  5   School Hours       3662 non-null   object
#  6   Enforcment By      2858 non-null   object
#  7   Restraints         3662 non-null   object
#  8   Force              3530 non-null   object
#  9   Type Of Force      3530 non-null   object
#  10  Top Charge         513 non-null    object
#  11  SummonsCharge      340 non-null    object
#  12  Classification     1190 non-null   object
#  13  Incident Location  3662 non-null   object
#  14  Scanning Incident  3662 non-null   object
# dtypes: object(15)
# memory usage: 457.8+ KB

# %%
df_first_half.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2299 entries, 0 to 1090
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      2299 non-null   object
#  1   Intervention Type  2299 non-null   object
#  2   Scanning Type      2299 non-null   object
#  3   School Related     2299 non-null   object
#  4   School Hours       2299 non-null   object
#  5   Enforcment By      2211 non-null   object
#  6   Restraints         2299 non-null   object
#  7   Force              2210 non-null   object
#  8   Top Charge         875 non-null    object
#  9   SummonsCharge      598 non-null    object
#  10  Classification     1893 non-null   object
#  11  Incident Location  2223 non-null   object
#  12  Scanning Incident  2216 non-null   object
#  13  Greater Than 21    1091 non-null   object
#  14  Type Of Force      1091 non-null   object
# dtypes: object(15)
# memory usage: 287.4+ KB

# %%
SSA_2016_df = pd.concat([df_first_half, df_second_half])

# %%
SSA_2016_df
# Out:
#                                           School Campus Intervention Type  \
# 0                                Abraham Lincoln HS(BS)          Arrested
# 1                                Abraham Lincoln HS(BS)          Arrested
# 2                                Abraham Lincoln HS(BS)          Arrested
# 3                                Abraham Lincoln HS(BS)   Child in Crisis
# 4                                Abraham Lincoln HS(BS)          Arrested
# ...                                                 ...               ...
# 2922                               WINGS ACADEMY(Bronx)         Mitigated
# 2923                               WINGS ACADEMY(Bronx)         Mitigated
# 2924                               WINGS ACADEMY(Bronx)         Mitigated
# 2925  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Juvenile Report
# 2926  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
#
#      Scanning Type School Related School Hours Enforcment By     Restraints  \
# ...

# %%
SSA_2016_df.to_csv('data/clean_SSA_Report_School_2016.csv', encoding='utf-8')
