# %%
# !pip install -r requirements.txt

# %%
import sklearn
import numpy as np
import pandas as pd

# %%
df_q1= pd.read_csv('data/ssa-report-school-1q-2017.csv')
df_q2 = pd.read_csv('data/ssa-report-school-2q-2017.csv')
df_q3 = pd.read_csv('data/ssa-report-school-3q-2017.csv')
df_q4 = pd.read_csv('data/ssa-report-school-4q-2017.csv')

# %%
df_q1
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1                                Abraham Lincoln HS(BS)          Arrested
# 2                                Abraham Lincoln HS(BS)          Arrested
# 3                                Abraham Lincoln HS(BS)          Arrested
# 4                                Abraham Lincoln HS(BS)          Arrested
# ...                                                 ...               ...
# 3296                               WINGS ACADEMY(Bronx)         Mitigated
# 3297                               WINGS ACADEMY(Bronx)         Mitigated
# 3298  WORLD ACADEMY FOR TOTAL COMMUNITY HEALTH HS-WA...         Mitigated
# 3299  WORLD ACADEMY FOR TOTAL COMMUNITY HEALTH HS-WA...         Mitigated
# 3300      Young Women Leadership School Astoria(Queens)         Mitigated
#
#      Incident Location Greator Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q1 = df_q1.rename(columns = {"Greator Than 21":"Greater Than 21"})

# %%
df_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3301 entries, 0 to 3300
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3301 non-null   object
#  1   Intervention Type  3301 non-null   object
#  2   Incident Location  3301 non-null   object
#  3   Greater Than 21    3301 non-null   object
#  4   Scanning Type      3301 non-null   object
#  5   Scanning Incident  3301 non-null   object
#  6   School Related     3301 non-null   object
#  7   School Hours       3301 non-null   object
#  8   Enforcment By      2520 non-null   object
#  9   Restraints         3301 non-null   object
#  10  Force              3133 non-null   object
#  11  Type Of Force      3131 non-null   object
#  12  Top Charge         398 non-null    object
#  13  SummonsCharge      291 non-null    object
#  14  Classification     1029 non-null   object
# dtypes: object(15)
# memory usage: 387.0+ KB

# %%
df_q2
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1                                Abraham Lincoln HS(BS)          Arrested
# 2                                Abraham Lincoln HS(BS)   Child in Crisis
# 3                                Abraham Lincoln HS(BS)   Child in Crisis
# 4                                Abraham Lincoln HS(BS)         mitigated
# ...                                                 ...               ...
# 2687             Yorkville Community School (Manhattan)   Child in Crisis
# 2688      Young Women Leadership School Astoria(Queens)         mitigated
# 2689  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Child in Crisis
# 2690  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
# 2691  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...         mitigated
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2692 entries, 0 to 2691
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      2692 non-null   object
#  1   Intervention Type  2692 non-null   object
#  2   Incident Location  2692 non-null   object
#  3   Greater Than 21    2692 non-null   object
#  4   Scanning Type      2692 non-null   object
#  5   Scanning Incident  2692 non-null   object
#  6   School Related     2692 non-null   object
#  7   School Hours       2692 non-null   object
#  8   Enforcment By      1903 non-null   object
#  9   Restraints         2692 non-null   object
#  10  Force              2692 non-null   object
#  11  Type Of Force      2692 non-null   object
#  12  Top Charge         329 non-null    object
#  13  SummonsCharge      202 non-null    object
#  14  Classification     795 non-null    object
# dtypes: object(15)
# memory usage: 315.6+ KB

# %%
df_q3
# Out:
#                                          School Campus Intervention Type  \
# 0    47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1    47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...           Summons
# 2                               Abraham Lincoln HS(BS)   Juvenile Report
# 3                               Abraham Lincoln HS(BS)         Mitigated
# 4             Academy for Environmental Leadership(BN)   Juvenile Report
# ..                                                 ...               ...
# 969                               WINGS ACADEMY(Bronx)           Summons
# 970                               WINGS ACADEMY(Bronx)           Summons
# 971  World Journalism Preparatory:A College Board S...           Summons
# 972  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...          Arrested
# 973  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Juvenile Report
#
#     Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      974 non-null    object
#  1   Intervention Type  974 non-null    object
#  2   Incident Location  974 non-null    object
#  3   Greater Than 21    974 non-null    object
#  4   Scanning Type      974 non-null    object
#  5   Scanning Incident  974 non-null    object
#  6   School Related     974 non-null    object
#  7   School Hours       974 non-null    object
#  8   Enforcment By      778 non-null    object
#  9   Restraints         974 non-null    object
#  10  Force              974 non-null    object
#  11  Type Of Force      974 non-null    object
#  12  Top Charge         119 non-null    object
#  13  SummonsCharge      85 non-null     object
#  14  Classification     277 non-null    object
# dtypes: object(15)
# memory usage: 114.3+ KB

# %%
df_q4
# Out:
#                                           School Campus Intervention Type  \
# 0                                Abraham Lincoln HS(BS)          Arrested
# 1                                Abraham Lincoln HS(BS)          Arrested
# 2                                Abraham Lincoln HS(BS)   Child in Crisis
# 3                                Abraham Lincoln HS(BS)   Child in Crisis
# 4                                Abraham Lincoln HS(BS)           Summons
# ...                                                 ...               ...
# 3632  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3633  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3634  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3635  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3636  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3637 entries, 0 to 3636
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3637 non-null   object
#  1   Intervention Type  3637 non-null   object
#  2   Incident Location  3637 non-null   object
#  3   Greater Than 21    3637 non-null   object
#  4   Scanning Type      3637 non-null   object
#  5   Scanning Incident  3637 non-null   object
#  6   School Related     3637 non-null   object
#  7   School Hours       3637 non-null   object
#  8   Enforcment By      2590 non-null   object
#  9   Restraints         3637 non-null   object
#  10  Force              3637 non-null   object
#  11  Type Of Force      3637 non-null   object
#  12  Top Charge         397 non-null    object
#  13  SummonsCharge      298 non-null    object
#  14  Classification     1041 non-null   object
# dtypes: object(15)
# memory usage: 426.3+ KB

# %%
df_first_half = pd.concat([df_q1, df_q2])

# %%
df_first_half
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1                                Abraham Lincoln HS(BS)          Arrested
# 2                                Abraham Lincoln HS(BS)          Arrested
# 3                                Abraham Lincoln HS(BS)          Arrested
# 4                                Abraham Lincoln HS(BS)          Arrested
# ...                                                 ...               ...
# 2687             Yorkville Community School (Manhattan)   Child in Crisis
# 2688      Young Women Leadership School Astoria(Queens)         mitigated
# 2689  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Child in Crisis
# 2690  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
# 2691  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...         mitigated
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_second_half = pd.concat([df_q3, df_q4])

# %%
df_second_half
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...           Summons
# 2                                Abraham Lincoln HS(BS)   Juvenile Report
# 3                                Abraham Lincoln HS(BS)         Mitigated
# 4              Academy for Environmental Leadership(BN)   Juvenile Report
# ...                                                 ...               ...
# 3632  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3633  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3634  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3635  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3636  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
SSA_2017_df = pd.concat([df_first_half, df_second_half])

# %%
SSA_2017_df
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1                                Abraham Lincoln HS(BS)          Arrested
# 2                                Abraham Lincoln HS(BS)          Arrested
# 3                                Abraham Lincoln HS(BS)          Arrested
# 4                                Abraham Lincoln HS(BS)          Arrested
# ...                                                 ...               ...
# 3632  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3633  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3634  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3635  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3636  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
SSA_2017_df.to_csv('data/clean_SSA_Report_School_2017.csv', encoding='utf-8')
