# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# ...
#   Using cached scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# ...
#   Using cached scipy-1.6.3-cp38-cp38-manylinux1_x86_64.whl (27.2 MB)
# ...
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# ...
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# ...

# %%
import sklearn
import numpy as np
import pandas as pd

# %%
df_q1= pd.read_csv('data/ssa-report-pct-1q-2020.csv')
df_q2 = pd.read_csv('data/ssa-report-pct-2q-2020.csv')
df_q3 = pd.read_csv('data/ssa-report-pct-3q-2020.csv')
df_q4 = pd.read_csv('data/ssa-report-pct-4q-2020.csv')
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (1,2,3,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_q1
# Out:
#       Pct Intervention Type     Restraints Gender   Age                Race
# 0       1          Arrested          Metal      M  17.0      White Hispanic
# 1       1   Child in Crisis  No Restraints      F  17.0  Asian/Pacific Isl.
# 2       1   Child in Crisis  No Restraints      F  16.0  Asian/Pacific Isl.
# 3       1   Child in Crisis  No Restraints      M  17.0              Arabic
# 4       1   Child in Crisis          Metal      M  17.0  Asian/Pacific Isl.
# ...   ...               ...            ...    ...   ...                 ...
# 3286  123         Mitigated  No Restraints      M  17.0      Black Hispanic
# 3287  123         Mitigated  No Restraints      M  15.0               White
# 3288  123         Mitigated  No Restraints      M  14.0               White
# 3289  123         Mitigated  No Restraints      F  15.0               White
# 3290  123         Mitigated  No Restraints      F  15.0               White
#
# [3291 rows x 6 columns]

# %%
df_q2
# Out:
#       Pct Intervention Type     Restraints Gender   Age                Race
# 0    79.0   Juvenile Report  No Restraints      M  11.0               Black
# 1    79.0   Juvenile Report  No Restraints      M  10.0               Black
# 2    83.0          Arrested          Metal      M  25.0      White Hispanic
# 3    83.0          Arrested          Metal      M  20.0      White Hispanic
# 4    83.0          Arrested          Metal      M  21.0      White Hispanic
# 5    83.0          Arrested          Metal      M  22.0      White Hispanic
# 6    70.0          Arrested          Metal      M  19.0      White Hispanic
# 7    70.0   Juvenile Report  No Restraints      M  17.0  Asian/Pacific Isl.
# 8    90.0          Arrested          Metal      M  22.0               Black
# 9    70.0          Arrested          Metal      M  14.0      White Hispanic
# 10    7.0          Arrested  No Restraints      M  28.0  Asian/Pacific Isl.
# ...

# %%
df_q3
# Out:
#           Pct Intervention     Restraints Gender   Age            Race
# 0        81.0    Mitigated  No Restraints      F  13.0           Black
# 1        81.0    Mitigated         Velcro      M   9.0           Black
# 2        62.0    Mitigated  No Restraints      M  30.0           Black
# 3         9.0    Mitigated  No Restraints      M  14.0  Black Hispanic
# 4         9.0    Mitigated  No Restraints      M  14.0  White Hispanic
# ...       ...          ...            ...    ...   ...             ...
# 1048568   NaN          NaN            NaN    NaN   NaN             NaN
# 1048569   NaN          NaN            NaN    NaN   NaN             NaN
# 1048570   NaN          NaN            NaN    NaN   NaN             NaN
# 1048571   NaN          NaN            NaN    NaN   NaN             NaN
# 1048572   NaN          NaN            NaN    NaN   NaN             NaN
#
# [1048573 rows x 6 columns]

# %%
df_q3 = df_q3.dropna(subset=["Pct"])

# %%
df_q3
# Out:
#       Pct     Intervention     Restraints Gender   Age            Race
# 0    81.0        Mitigated  No Restraints      F  13.0           Black
# 1    81.0        Mitigated         Velcro      M   9.0           Black
# 2    62.0        Mitigated  No Restraints      M  30.0           Black
# 3     9.0        Mitigated  No Restraints      M  14.0  Black Hispanic
# 4     9.0        Mitigated  No Restraints      M  14.0  White Hispanic
# 5    25.0        Mitigated  No Restraints      F  20.0           Black
# 6    34.0        Mitigated  No Restraints      M   NaN  White Hispanic
# 7    18.0        Mitigated  No Restraints      M  14.0  White Hispanic
# 8    18.0        Mitigated  No Restraints      M  14.0           Black
# 9    18.0        Mitigated  No Restraints      M  14.0           Black
# 10  109.0          Summons  No Restraints      M  66.0  White Hispanic
# 11  113.0         Arrested          Metal      M  15.0           Black
# ...

# %%
df_q3 = df_q3.rename(columns = {"Intervention":"Intervention Type"})

# %%
df_q4
# Out:
#           Pct Intervention Type     Restraints Gender   Age      Race
# 0        81.0   Juvenile Report  No Restraints      M  14.0     Black
# 1        77.0         Mitigated  No Restraints      F  34.0  Hispanic
# 2        77.0         Mitigated  No Restraints      M  34.0     Black
# 3        83.0         Mitigated  No Restraints      F  15.0  Hispanic
# 4        71.0         Mitigated  No Restraints      M  16.0  Hispanic
# ...       ...               ...            ...    ...   ...       ...
# 1048559   NaN               NaN            NaN    NaN   NaN       NaN
# 1048560   NaN               NaN            NaN    NaN   NaN       NaN
# 1048561   NaN               NaN            NaN    NaN   NaN       NaN
# 1048562   NaN               NaN            NaN    NaN   NaN       NaN
# 1048563   NaN               NaN            NaN    NaN   NaN       NaN
#
# [1048564 rows x 6 columns]

# %%
df_q4 = df_q4.dropna(subset=["Pct"])

# %%
df_q4
# Out:
#       Pct Intervention Type     Restraints Gender   Age      Race
# 0    81.0   Juvenile Report  No Restraints      M  14.0     Black
# 1    77.0         Mitigated  No Restraints      F  34.0  Hispanic
# 2    77.0         Mitigated  No Restraints      M  34.0     Black
# 3    83.0         Mitigated  No Restraints      F  15.0  Hispanic
# 4    71.0         Mitigated  No Restraints      M  16.0  Hispanic
# ..    ...               ...            ...    ...   ...       ...
# 104  14.0   Child in Crisis  No Restraints      F  17.0  Hispanic
# 105  72.0         Mitigated  No Restraints      M   6.0  Hispanic
# 106  61.0         Mitigated  No Restraints      M   9.0     White
# 107  72.0   Child in Crisis  No Restraints      M  10.0  Hispanic
# 108  44.0   Child in Crisis  No Restraints      M  16.0  Hispanic
#
# [109 rows x 6 columns]

# %%
df_first_half = pd.concat([df_q1, df_q2])

# %%
df_first_half
# Out:
#     Pct Intervention Type     Restraints Gender   Age                Race
# 0   1.0          Arrested          Metal      M  17.0      White Hispanic
# 1   1.0   Child in Crisis  No Restraints      F  17.0  Asian/Pacific Isl.
# 2   1.0   Child in Crisis  No Restraints      F  16.0  Asian/Pacific Isl.
# 3   1.0   Child in Crisis  No Restraints      M  17.0              Arabic
# 4   1.0   Child in Crisis          Metal      M  17.0  Asian/Pacific Isl.
# ..  ...               ...            ...    ...   ...                 ...
# 32  NaN               NaN            NaN    NaN   NaN                 NaN
# 33  NaN               NaN            NaN    NaN   NaN                 NaN
# 34  NaN               NaN            NaN    NaN   NaN                 NaN
# 35  NaN               NaN            NaN    NaN   NaN                 NaN
# 36  NaN               NaN            NaN    NaN   NaN                 NaN
#
# [3328 rows x 6 columns]

# %%
df_second_half = pd.concat([df_q3, df_q4])

# %%
df_second_half
# Out:
#       Pct Intervention Type     Restraints Gender   Age            Race
# 0    81.0         Mitigated  No Restraints      F  13.0           Black
# 1    81.0         Mitigated         Velcro      M   9.0           Black
# 2    62.0         Mitigated  No Restraints      M  30.0           Black
# 3     9.0         Mitigated  No Restraints      M  14.0  Black Hispanic
# 4     9.0         Mitigated  No Restraints      M  14.0  White Hispanic
# ..    ...               ...            ...    ...   ...             ...
# 104  14.0   Child in Crisis  No Restraints      F  17.0        Hispanic
# 105  72.0         Mitigated  No Restraints      M   6.0        Hispanic
# 106  61.0         Mitigated  No Restraints      M   9.0           White
# 107  72.0   Child in Crisis  No Restraints      M  10.0        Hispanic
# 108  44.0   Child in Crisis  No Restraints      M  16.0        Hispanic
#
# [134 rows x 6 columns]

# %%
SSA_2020_PCT_df = pd.concat([df_first_half, df_second_half])

# %%
SSA_2020_PCT_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3462 entries, 0 to 108
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pct                3448 non-null   float64
#  1   Intervention Type  3448 non-null   object
#  2   Restraints         3448 non-null   object
#  3   Gender             3448 non-null   object
#  4   Age                3362 non-null   float64
#  5   Race               3448 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 189.3+ KB

# %%
SSA_2020_PCT_df.to_csv('data/clean_SSA_2020_PCT.csv', encoding='utf-8')
