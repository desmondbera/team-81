# %%
# !pip install -r requirements.txt

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df = pd.read_csv('data/demographic-snapshot-2016-17-to-2020-21-public-school.csv')
df.head()
# Out:
#       DBN                School Name     Year Total Enrollment  \
# 0  01M015  P.S. 015 Roberto Clemente  2016-17              178
# 1  01M015  P.S. 015 Roberto Clemente  2017-18              190
# 2  01M015  P.S. 015 Roberto Clemente  2018-19              174
# 3  01M015  P.S. 015 Roberto Clemente  2019-20              190
# 4  01M015  P.S. 015 Roberto Clemente  2020-21              193
#
#   Grade 3K+PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  Grade 3  \
# 0                                17       28       33       27       31
# 1                                17       28       32       33       23
# 2                                13       20       33       30       30
# 3                                14       29       28       38       33
# 4                                17       29       29       27       30
#
#    Grade 4  ...  % White  # Missing Race/Ethnicity Data  \
# 0       24  ...     2.2%                              0
# ...

# %%
df.shape
# Out:
# (9169, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9169 entries, 0 to 9168
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   DBN                                9169 non-null   object
#  1   School Name                        9169 non-null   object
#  2   Year                               9169 non-null   object
#  3   Total Enrollment                   9169 non-null   object
#  4   Grade 3K+PK (Half Day & Full Day)  9169 non-null   object
#  5   Grade K                            9169 non-null   int64
#  6   Grade 1                            9169 non-null   int64
#  7   Grade 2                            9169 non-null   int64
#  8   Grade 3                            9169 non-null   int64
#  9   Grade 4                            9169 non-null   int64
#  10  Grade 5                            9169 non-null   int64
# ...

# %%
# df['Grade K'] = df['Grade K'].str.split(',').str.join('').astype(int)
# df['Grade 1'] = df['Grade 1'].str.split(',').str.join('').astype(int)
# df['Grade 2'] = df['Grade 2'].str.split(',').str.join('').astype(int)
# df['Grade 3'] = df['Grade 3'].str.split(',').str.join('').astype(int)
# df['Grade 4'] = df['Grade 4'].str.split(',').str.join('').astype(int)
# df['Grade 5'] = df['Grade 5'].str.split(',').str.join('').astype(int)
# df['Grade 6'] = df['Grade 6'].str.split(',').str.join('').astype(int)
# df['Grade 7'] = df['Grade 7'].str.split(',').str.join('').astype(int)
# df['Grade 8'] = df['Grade 8'].str.split(',').str.join('').astype(int)
df['Grade 9'] = df['Grade 9'].str.split(',').str.join('').astype(int)
df['Grade 10'] = df['Grade 10'].str.split(',').str.join('').astype(int)
df['Grade 11'] = df['Grade 11'].str.split(',').str.join('').astype(int)
df['Grade 12'] = df['Grade 12'].str.split(',').str.join('').astype(int)
df['Total Enrollment'] = df['Total Enrollment'].str.split(',').str.join('').astype(int)
df['Grade 3K+PK (Half Day & Full Day)'] = df['Grade 3K+PK (Half Day & Full Day)'].str.split(',').str.join('').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9169 entries, 01M015 to 84X730
# Data columns (total 42 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   School Name                        9169 non-null   object
#  1   Year                               9169 non-null   object
#  2   Total Enrollment                   9169 non-null   int64
#  3   Grade 3K+PK (Half Day & Full Day)  9169 non-null   int64
#  4   Grade K                            9169 non-null   int64
#  5   Grade 1                            9169 non-null   int64
#  6   Grade 2                            9169 non-null   int64
#  7   Grade 3                            9169 non-null   int64
#  8   Grade 4                            9169 non-null   int64
#  9   Grade 5                            9169 non-null   int64
#  10  Grade 6                            9169 non-null   int64
# ...

# %%
len(df)
# Out:
# 9169

# %%
df.describe()
# Out:
#        Total Enrollment  Grade 3K+PK (Half Day & Full Day)      Grade K  \
# count       9169.000000                        9169.000000  9169.000000
# mean         585.955611                          17.964336    42.770967
# std          477.226538                          48.498976    49.799159
# min            7.000000                           0.000000     0.000000
# 25%          320.000000                           0.000000     0.000000
# 50%          471.000000                           0.000000    30.000000
# 75%          687.000000                          32.000000    75.000000
# max         6040.000000                        1328.000000   344.000000
#
#            Grade 1      Grade 2      Grade 3      Grade 4      Grade 5  \
# count  9169.000000  9169.000000  9169.000000  9169.000000  9169.000000
# mean     44.196859    44.303305    44.298397    44.197622    43.992257
# std      51.404563    52.081540    53.423370    54.509121    54.500713
# ...

# %%
df.isnull().sum()
# Out:
# DBN                                  0
# School Name                          0
# Year                                 0
# Total Enrollment                     0
# Grade 3K+PK (Half Day & Full Day)    0
# Grade K                              0
# Grade 1                              0
# Grade 2                              0
# Grade 3                              0
# Grade 4                              0
# Grade 5                              0
# Grade 6                              0
# Grade 7                              0
# Grade 8                              0
# Grade 9                              0
# Grade 10                             0
# Grade 11                             0
# Grade 12                             0
# # Female                             0
# % Female                             0
# # Male                               0
# % Male                               0
# # Asian                              0
# % Asian                              0
# ...

# %%
df.nunique()
# Out:
# DBN                                  1879
# School Name                          1870
# Year                                    5
# Total Enrollment                     1598
# Grade 3K+PK (Half Day & Full Day)     188
# Grade K                               245
# Grade 1                               249
# Grade 2                               255
# Grade 3                               273
# Grade 4                               275
# Grade 5                               277
# Grade 6                               445
# Grade 7                               452
# Grade 8                               453
# Grade 9                               485
# Grade 10                              477
# Grade 11                              447
# Grade 12                              447
# # Female                              963
# % Female                              627
# # Male                                995
# % Male                                623
# ...

# %%
df
# Out:
#          DBN                        School Name     Year  Total Enrollment  \
# 0     01M015          P.S. 015 Roberto Clemente  2016-17               178
# 1     01M015          P.S. 015 Roberto Clemente  2017-18               190
# 2     01M015          P.S. 015 Roberto Clemente  2018-19               174
# 3     01M015          P.S. 015 Roberto Clemente  2019-20               190
# 4     01M015          P.S. 015 Roberto Clemente  2020-21               193
# ...      ...                                ...      ...               ...
# 9164  84X730  Bronx Charter School for the Arts  2016-17               320
# 9165  84X730  Bronx Charter School for the Arts  2017-18               314
# 9166  84X730  Bronx Charter School for the Arts  2018-19               430
# 9167  84X730  Bronx Charter School for the Arts  2019-20               523
# 9168  84X730  Bronx Charter School for the Arts  2020-21               626
#
# ...

# %%
df.tail()
# Out:
#          DBN                        School Name     Year  Total Enrollment  \
# 9164  84X730  Bronx Charter School for the Arts  2016-17               320
# 9165  84X730  Bronx Charter School for the Arts  2017-18               314
# 9166  84X730  Bronx Charter School for the Arts  2018-19               430
# 9167  84X730  Bronx Charter School for the Arts  2019-20               523
# 9168  84X730  Bronx Charter School for the Arts  2020-21               626
#
#       Grade 3K+PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  Grade 3  \
# 9164                                  0       53       53       55       52
# 9165                                  0       50       51       54       51
# 9166                                  0       49       54       49       54
# 9167                                  0       51       50       53       52
# 9168                                  0       38       52       53       55
#
# ...

# %%
df = pd.read_csv('data/demographic-snapshot-2016-17-to-2020-21-public-school.csv', 
                 index_col=0, parse_dates=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9169 entries, 01M015 to 84X730
# Data columns (total 42 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   School Name                        9169 non-null   object
#  1   Year                               9169 non-null   object
#  2   Total Enrollment                   9169 non-null   object
#  3   Grade 3K+PK (Half Day & Full Day)  9169 non-null   object
#  4   Grade K                            9169 non-null   int64
#  5   Grade 1                            9169 non-null   int64
#  6   Grade 2                            9169 non-null   int64
#  7   Grade 3                            9169 non-null   int64
#  8   Grade 4                            9169 non-null   int64
#  9   Grade 5                            9169 non-null   int64
#  10  Grade 6                            9169 non-null   int64
# ...

# %%
df.head()
# Out:
#                       School Name     Year Total Enrollment  \
# DBN
# 01M015  P.S. 015 Roberto Clemente  2016-17              178
# 01M015  P.S. 015 Roberto Clemente  2017-18              190
# 01M015  P.S. 015 Roberto Clemente  2018-19              174
# 01M015  P.S. 015 Roberto Clemente  2019-20              190
# 01M015  P.S. 015 Roberto Clemente  2020-21              193
#
#        Grade 3K+PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  Grade 3  \
# DBN
# 01M015                                17       28       33       27       31
# 01M015                                17       28       32       33       23
# 01M015                                13       20       33       30       30
# 01M015                                14       29       28       38       33
# 01M015                                17       29       29       27       30
#
#         Grade 4  Grade 5  ...  % White  # Missing Race/Ethnicity Data  \
# DBN                       ...
# ...

# %%
df.shape
# Out:
# (9169, 42)

# %%
# identify outliers with standard deviation
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import std
# seed the random number generator
seed(1)
# generate univariate observations
df_data = 5 * randn(9169) + 50
# calculate summary statistics
data_mean, data_std = mean(df_data), std(df_data)
# identify outliers
cut_off = data_std * 3
lower, upper = data_mean - cut_off, data_mean + cut_off
# identify outliers
outliers = [x for x in df_data if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))
# remove outliers
outliers_removed = [x for x in df_data if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Identified outliers: 26
# Non-outlier observations: 9143

# %%
...
# calculate summary statistics
data_mean, data_std = mean(data), std(data)
# identify outliers
cut_off = data_std * 3
lower, upper = data_mean - cut_off, data_mean + cut_off
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-45dd05049bfe> in <module>
#       1 ...
#       2 # calculate summary statistics
# ----> 3 data_mean, data_std = mean(data), std(data)
#       4 # identify outliers
#       5 cut_off = data_std * 3
#
# NameError: name 'data' is not defined

# %%
...
# identify outliers
outliers = [x for x in data if x < lower or x > upper]
outliers

# %%
# evaluate model on the raw dataset
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
# load the dataset
# url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.csv'
df = read_csv('data/demographic-snapshot-2016-17-to-2020-21-public-school.csv', header=None)
# retrieve the array
data = df.values
# split into inpiut and output elements
X, y = data[:, :-1], data[:, -1]
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# fit the model
model = LinearRegression()
model.fit(X_train, y_train)
# evaluate the model
yhat = model.predict(X_test)
# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)

# %%
df.head()
# Out:
#                       School Name     Year Total Enrollment  \
# DBN
# 01M015  P.S. 015 Roberto Clemente  2016-17              178
# 01M015  P.S. 015 Roberto Clemente  2017-18              190
# 01M015  P.S. 015 Roberto Clemente  2018-19              174
# 01M015  P.S. 015 Roberto Clemente  2019-20              190
# 01M015  P.S. 015 Roberto Clemente  2020-21              193
#
#        Grade 3K+PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  Grade 3  \
# DBN
# 01M015                                17       28       33       27       31
# 01M015                                17       28       32       33       23
# 01M015                                13       20       33       30       30
# 01M015                                14       29       28       38       33
# 01M015                                17       29       29       27       30
#
#         Grade 4  Grade 5  ...  % White  # Missing Race/Ethnicity Data  \
# DBN                       ...
# ...

# %%
df.to_csv('data/clean_demographic_snapshot_schools.csv', encoding='utf-8')
