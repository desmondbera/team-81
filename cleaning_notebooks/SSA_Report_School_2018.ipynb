# %%
# !pip install -r requirements.txt

# %%
import sklearn
import numpy as np
import pandas as pd

# %%
df_q1= pd.read_csv('data/ssa-report-school-1q-2018.csv')
df_q2 = pd.read_csv('data/ssa-report-school-2q-2018.csv')
df_q3 = pd.read_csv('data/ssa-report-school-3q-2018.csv')
df_q4 = pd.read_csv('data/ssa-report-school-4q-2018.csv')

# %%
df_q1
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Juvenile Report
# 2                                Abraham Lincoln HS(BS)         Mitigated
# 3                                Abraham Lincoln HS(BS)         Mitigated
# 4                                Abraham Lincoln HS(BS)         Mitigated
# ...                                                 ...               ...
# 3458          YALA MANHATTAN LEARNING CENTER(Manhattan)           Summons
# 3459      Young Women Leadership School Astoria(Queens)   Child in Crisis
# 3460  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3461  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...          Arrested
# 3462  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Child in Crisis
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3463 entries, 0 to 3462
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3463 non-null   object
#  1   Intervention Type  3463 non-null   object
#  2   Incident Location  3463 non-null   object
#  3   Greater Than 21    3463 non-null   object
#  4   Scanning Type      3463 non-null   object
#  5   Scanning Incident  3463 non-null   object
#  6   School Related     3463 non-null   object
#  7   School Hours       3463 non-null   object
#  8   Enforcment By      2476 non-null   object
#  9   Restraints         3463 non-null   object
#  10  Force              3463 non-null   object
#  11  Type Of Force      3463 non-null   object
#  12  Top Charge         320 non-null    object
#  13  SummonsCharge      286 non-null    object
#  14  Classification     924 non-null    object
# dtypes: object(15)
# memory usage: 405.9+ KB

# %%
df_q2
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Juvenile Report
# 1     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 2                                Abraham Lincoln HS(BS)         Mitigated
# 3                                Abraham Lincoln HS(BS)         Mitigated
# 4                                Abraham Lincoln HS(BS)         Mitigated
# ...                                                 ...               ...
# 3117                Womens Academy of Excellence(Bronx)         Mitigated
# 3118                Womens Academy of Excellence(Bronx)   Child in Crisis
# 3119                   Yorkville East Middle School(MN)   Juvenile Report
# 3120  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3121  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Child in Crisis
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3122 entries, 0 to 3121
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3122 non-null   object
#  1   Intervention Type  3122 non-null   object
#  2   Incident Location  3122 non-null   object
#  3   Greater Than 21    3122 non-null   object
#  4   Scanning Type      3122 non-null   object
#  5   Scanning Incident  3122 non-null   object
#  6   School Related     3122 non-null   object
#  7   School Hours       3122 non-null   object
#  8   Enforcment By      2128 non-null   object
#  9   Restraints         3122 non-null   object
#  10  Force              3122 non-null   object
#  11  Type Of Force      3122 non-null   object
#  12  Top Charge         336 non-null    object
#  13  SummonsCharge      216 non-null    object
#  14  Classification     843 non-null    object
#  15  Unnamed: 15        0 non-null      float64
# ...

# %%
# del df_q2["Unnamed: 16"]
# del df_q2["Unnamed: 17"]
del df_q2["Unnamed: 15"]
del df_q2["Unnamed: 18"]
del df_q2["Unnamed: 19"]
del df_q2["Unnamed: 20"]
del df_q2["Unnamed: 21"]
del df_q2["Unnamed: 22"]
del df_q2["Unnamed: 23"]
del df_q2["Unnamed: 24"]
del df_q2["Unnamed: 25"]
del df_q2["Unnamed: 26"]
del df_q2["Unnamed: 27"]
del df_q2["Unnamed: 28"]
del df_q2["Unnamed: 29"]
del df_q2["Unnamed: 30"]
del df_q2["Unnamed: 31"]
del df_q2["Unnamed: 32"]
del df_q2["Unnamed: 33"]
del df_q2["Unnamed: 34"]

# %%
df_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3122 entries, 0 to 3121
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3122 non-null   object
#  1   Intervention Type  3122 non-null   object
#  2   Incident Location  3122 non-null   object
#  3   Greater Than 21    3122 non-null   object
#  4   Scanning Type      3122 non-null   object
#  5   Scanning Incident  3122 non-null   object
#  6   School Related     3122 non-null   object
#  7   School Hours       3122 non-null   object
#  8   Enforcment By      2128 non-null   object
#  9   Restraints         3122 non-null   object
#  10  Force              3122 non-null   object
#  11  Type Of Force      3122 non-null   object
#  12  Top Charge         336 non-null    object
#  13  SummonsCharge      216 non-null    object
#  14  Classification     843 non-null    object
# dtypes: object(15)
# memory usage: 366.0+ KB

# %%
df_q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   School Campus       960 non-null    object
#  1   Intervention Type   960 non-null    object
#  2   Incident Location   960 non-null    object
#  3   Greater Than 21     960 non-null    object
#  4   Scanning Type       960 non-null    object
#  5   Scanning Incident   960 non-null    object
#  6   School Related      960 non-null    object
#  7   School Hours        960 non-null    object
#  8   Enforcment By       747 non-null    object
#  9   Restraints          960 non-null    object
#  10  Force               960 non-null    object
#  11  Type Of Force       960 non-null    object
#  12  Top Charge          110 non-null    object
#  13  SummonsCharge       80 non-null     object
#  14  Classification      297 non-null    object
# dtypes: object(15)
# ...

# %%
df_q3 = df_q3.rename(columns = {"Greater than 21":"Greater Than 21"})

# %%
df_q3 = df_q3.rename(columns = {"Incident Location ":"Incident Location"})

# %%
df_q4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3710 entries, 0 to 3709
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3710 non-null   object
#  1   Intervention Type  3710 non-null   object
#  2   Incident Location  3710 non-null   object
#  3   Greater Than 21    3710 non-null   object
#  4   Scanning Type      3710 non-null   object
#  5   Scanning Incident  3710 non-null   object
#  6   School Related     3710 non-null   object
#  7   School Hours       3710 non-null   object
#  8   Enforcment By      2584 non-null   object
#  9   Restraints         3710 non-null   object
#  10  Force              3710 non-null   object
#  11  Type Of Force      3710 non-null   object
#  12  Top Charge         296 non-null    object
#  13  SummonsCharge      124 non-null    object
#  14  Classification     815 non-null    object
# dtypes: object(15)
# memory usage: 434.9+ KB

# %%
df_q4 = df_q4.rename(columns = {"Incident Location ":"Incident Location"})

# %%
df_first_half = pd.concat([df_q1, df_q2])

# %%
df_first_half
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Juvenile Report
# 2                                Abraham Lincoln HS(BS)         Mitigated
# 3                                Abraham Lincoln HS(BS)         Mitigated
# 4                                Abraham Lincoln HS(BS)         Mitigated
# ...                                                 ...               ...
# 3117                Womens Academy of Excellence(Bronx)         Mitigated
# 3118                Womens Academy of Excellence(Bronx)   Child in Crisis
# 3119                   Yorkville East Middle School(MN)   Juvenile Report
# 3120  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...         Mitigated
# 3121  YOUNG WOMEN LEADERSHIP SCHOOL QUEENS CAMPUS(Qu...   Child in Crisis
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_first_half.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6585 entries, 0 to 3121
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      6585 non-null   object
#  1   Intervention Type  6585 non-null   object
#  2   Incident Location  6585 non-null   object
#  3   Greater Than 21    6585 non-null   object
#  4   Scanning Type      6585 non-null   object
#  5   Scanning Incident  6585 non-null   object
#  6   School Related     6585 non-null   object
#  7   School Hours       6585 non-null   object
#  8   Enforcment By      4604 non-null   object
#  9   Restraints         6585 non-null   object
#  10  Force              6585 non-null   object
#  11  Type Of Force      6585 non-null   object
#  12  Top Charge         656 non-null    object
#  13  SummonsCharge      502 non-null    object
#  14  Classification     1767 non-null   object
# dtypes: object(15)
# memory usage: 823.1+ KB

# %%
df_second_half = pd.concat([df_q3, df_q4])

# %%
df_second_half
# Out:
#                                          School Campus Intervention Type  \
# 0                               Abraham Lincoln HS(BS)          Arrested
# 1                               Abraham Lincoln HS(BS)          Arrested
# 2                               Abraham Lincoln HS(BS)          Arrested
# 3                               Abraham Lincoln HS(BS)   Juvenile Report
# 4                               Abraham Lincoln HS(BS)           Summons
# ...                                                ...               ...
# 3705                              WINGS ACADEMY(Bronx)         Mitigated
# 3706                              WINGS ACADEMY(Bronx)         Mitigated
# 3707                              WINGS ACADEMY(Bronx)   Child in Crisis
# 3708  Young Women's Leadership School of the Bronx(XW)         Mitigated
# 3709  Young Women's Leadership School of the Bronx(XW)   Juvenile Report
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_second_half.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4670 entries, 0 to 3709
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      4670 non-null   object
#  1   Intervention Type  4670 non-null   object
#  2   Incident Location  4670 non-null   object
#  3   Greater Than 21    4670 non-null   object
#  4   Scanning Type      4670 non-null   object
#  5   Scanning Incident  4670 non-null   object
#  6   School Related     4670 non-null   object
#  7   School Hours       4670 non-null   object
#  8   Enforcment By      3331 non-null   object
#  9   Restraints         4670 non-null   object
#  10  Force              4670 non-null   object
#  11  Type Of Force      4670 non-null   object
#  12  Top Charge         406 non-null    object
#  13  SummonsCharge      204 non-null    object
#  14  Classification     1112 non-null   object
# dtypes: object(15)
# memory usage: 583.8+ KB

# %%
SSA_2018_df = pd.concat([df_first_half, df_second_half])

# %%
SSA_2018_df
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Child in Crisis
# 1     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...   Juvenile Report
# 2                                Abraham Lincoln HS(BS)         Mitigated
# 3                                Abraham Lincoln HS(BS)         Mitigated
# 4                                Abraham Lincoln HS(BS)         Mitigated
# ...                                                 ...               ...
# 3705                               WINGS ACADEMY(Bronx)         Mitigated
# 3706                               WINGS ACADEMY(Bronx)         Mitigated
# 3707                               WINGS ACADEMY(Bronx)   Child in Crisis
# 3708   Young Women's Leadership School of the Bronx(XW)         Mitigated
# 3709   Young Women's Leadership School of the Bronx(XW)   Juvenile Report
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
SSA_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11255 entries, 0 to 3709
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      11255 non-null  object
#  1   Intervention Type  11255 non-null  object
#  2   Incident Location  11255 non-null  object
#  3   Greater Than 21    11255 non-null  object
#  4   Scanning Type      11255 non-null  object
#  5   Scanning Incident  11255 non-null  object
#  6   School Related     11255 non-null  object
#  7   School Hours       11255 non-null  object
#  8   Enforcment By      7935 non-null   object
#  9   Restraints         11255 non-null  object
#  10  Force              11255 non-null  object
#  11  Type Of Force      11255 non-null  object
#  12  Top Charge         1062 non-null   object
#  13  SummonsCharge      706 non-null    object
#  14  Classification     2879 non-null   object
# dtypes: object(15)
# memory usage: 1.4+ MB

# %%
SSA_2018_df.to_csv('data/clean_SSA_Report_School_2018.csv', encoding='utf-8')
