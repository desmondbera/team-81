# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# ...
#   Using cached scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# ...
#   Using cached scipy-1.6.3-cp38-cp38-manylinux1_x86_64.whl (27.2 MB)
# ...
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# ...
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# ...

# %%
import sklearn
import numpy as np
import pandas as pd

# %%
df_q1= pd.read_csv('data/ssa-report-school-1q-2019.csv')
df_q2 = pd.read_csv('data/ssa-report-school-2q-2019.csv')
df_q3 = pd.read_csv('data/ssa-report-school-3q-2019.csv')
df_q4 = pd.read_csv('data/ssa-report-school-4q-2019.csv')

# %%
df_q1
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...         Mitigated
# 1                                Abraham Lincoln HS(BS)           Summons
# 2                                Abraham Lincoln HS(BS)   Juvenile Report
# 3                                Abraham Lincoln HS(BS)          Arrested
# 4                                Abraham Lincoln HS(BS)         Mitigated
# ...                                                 ...               ...
# 3582                               WINGS ACADEMY(Bronx)         Mitigated
# 3583                               WINGS ACADEMY(Bronx)   Juvenile Report
# 3584  WORLD ACADEMY FOR TOTAL COMMUNITY HEALTH HS-WA...         Mitigated
# 3585  WORLD ACADEMY FOR TOTAL COMMUNITY HEALTH HS-WA...         Mitigated
# 3586      Young Women Leadership School Astoria(Queens)          Arrested
#
#      Incident Location Greator Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3587 entries, 0 to 3586
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3587 non-null   object
#  1   Intervention Type  3587 non-null   object
#  2   Incident Location  3587 non-null   object
#  3   Greator Than 21    3587 non-null   object
#  4   Scanning Type      3587 non-null   object
#  5   Scanning Incident  3587 non-null   object
#  6   School Related     3587 non-null   object
#  7   School Hours       3587 non-null   object
#  8   Enforcment By      2538 non-null   object
#  9   Restraints         3587 non-null   object
#  10  Force              3587 non-null   object
#  11  Type Of Force      3587 non-null   object
#  12  Top Charge         231 non-null    object
#  13  SummonsCharge      129 non-null    object
#  14  Classification     836 non-null    object
# dtypes: object(15)
# memory usage: 420.5+ KB

# %%
df_q1 = df_q1.rename(columns = {"Greator Than 21":"Greater Than 21"})

# %%
df_q2
# Out:
#                                           School Campus Intervention Type  \
# 0                               Adlai Stevenson HS(XE)          Mitigated
# 1                               Adlai Stevenson HS(XE)    Juvenile Report
# 2                                 BEACH CHANNEL HS(QS)    Juvenile Report
# 3                              BENJAMIN CARDOZO HS(QN)            Summons
# 4                                EVANDER CHILDS HS(XE)           Arrested
# ...                                                 ...               ...
# 3239                                        JHS 113(XE)   Juvenile Report
# 3240                           PS 142 Amalia Castro(MS)   Child in Crisis
# 3241                             EVANDER CHILDS HS(XE)    Juvenile Report
# 3242                                         IS 218(BN)          Arrested
# 3243  THE URBAN ASSEMBLY SCHOOL FOR MEDIA STUDIES(ML...          Arrested
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q2 = df_q2.rename(columns = {"Summons Charge":"SummonsCharge"})

# %%
df_q2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3244 entries, 0 to 3243
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3244 non-null   object
#  1   Intervention Type  3244 non-null   object
#  2   Incident Location  3244 non-null   object
#  3   Greater Than 21    3244 non-null   object
#  4   Scanning Type      3244 non-null   object
#  5   Scanning Incident  3244 non-null   object
#  6   School Related     3244 non-null   object
#  7   School Hours       3244 non-null   object
#  8   Enforcment By      2367 non-null   object
#  9   Restraints         3244 non-null   object
#  10  Force              3244 non-null   object
#  11  Type Of Force      3244 non-null   object
#  12  Top Charge         246 non-null    object
#  13  SummonsCharge      115 non-null    object
#  14  Classification     676 non-null    object
# dtypes: object(15)
# memory usage: 380.3+ KB

# %%
df_q3
# Out:
#                                           School Campus Intervention Type  \
# 0                                Abraham Lincoln HS(BS)         Mitigated
# 1                                Abraham Lincoln HS(BS)         Mitigated
# 2                                Abraham Lincoln HS(BS)         Mitigated
# 3                  Academy for Integrated Learning (BN)         Mitigated
# 4                  Academy for Integrated Learning (BN)         Mitigated
# ...                                                 ...               ...
# 1144                               WINGS ACADEMY(Bronx)           Summons
# 1145                Womens Academy of Excellence(Bronx)   Child in Crisis
# 1146             Yorkville Community School (Manhattan)   Child in Crisis
# 1147  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
# 1148                                                NaN               NaN
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
del df_q3["Unnamed: 15"]

# %%
del df_q3["Unnamed: 16"]
del df_q3["Unnamed: 17"]

# %%
df_q3
# Out:
#                                           School Campus Intervention Type  \
# 0                                Abraham Lincoln HS(BS)         Mitigated
# 1                                Abraham Lincoln HS(BS)         Mitigated
# 2                                Abraham Lincoln HS(BS)         Mitigated
# 3                  Academy for Integrated Learning (BN)         Mitigated
# 4                  Academy for Integrated Learning (BN)         Mitigated
# ...                                                 ...               ...
# 1144                               WINGS ACADEMY(Bronx)           Summons
# 1145                Womens Academy of Excellence(Bronx)   Child in Crisis
# 1146             Yorkville Community School (Manhattan)   Child in Crisis
# 1147  YOUNG WOMEN LEADERSHIP SCHOOL/MANHATTAN CAMPUS...   Child in Crisis
# 1148                                                NaN               NaN
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_q3 = df_q3.dropna(subset=["School Campus"])

# %%
df_q3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1148 entries, 0 to 1147
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      1148 non-null   object
#  1   Intervention Type  1148 non-null   object
#  2   Incident Location  1148 non-null   object
#  3   Greater Than 21    1148 non-null   object
#  4   Scanning Type      1148 non-null   object
#  5   Scanning Incident  1148 non-null   object
#  6   School Related     1148 non-null   object
#  7   School Hours       1148 non-null   object
#  8   Enforcment By      869 non-null    object
#  9   Restraints         1148 non-null   object
#  10  Force              1148 non-null   object
#  11  Type Of Force      1148 non-null   object
#  12  Top Charge         76 non-null     object
#  13  SummonsCharge      36 non-null     object
#  14  Classification     250 non-null    object
# dtypes: object(15)
# memory usage: 143.5+ KB

# %%
df_q4
# Out:
#                                   School Campus Intervention Type  \
# 0                        Abraham Lincoln HS(BS)          Arrested
# 1                        Abraham Lincoln HS(BS)   Child in Crisis
# 2                        Abraham Lincoln HS(BS)         Mitigated
# 3      Academy for Environmental Leadership(BN)   Juvenile Report
# 4      Academy for Environmental Leadership(BN)         Mitigated
# ...                                         ...               ...
# 3455                       WINGS ACADEMY(Bronx)           Summons
# 3456                       WINGS ACADEMY(Bronx)           Summons
# 3457                       WINGS ACADEMY(Bronx)           Summons
# 3458                       WINGS ACADEMY(Bronx)           Summons
# 3459  YALA MANHATTAN LEARNING CENTER(Manhattan)           Summons
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# 0              On-Site              NO  Non-Scanning                 N
# ...

# %%
df_q4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3460 entries, 0 to 3459
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   School Campus      3460 non-null   object
#  1   Intervention Type  3460 non-null   object
#  2   Incident Location  3460 non-null   object
#  3   Greater Than 21    3460 non-null   object
#  4   Scanning Type      3458 non-null   object
#  5   Scanning Incident  3460 non-null   object
#  6   School Related     3460 non-null   object
#  7   School Hours       3460 non-null   object
#  8   Enforcment By      2528 non-null   object
#  9   Restraints         3460 non-null   object
#  10  Force              3460 non-null   object
#  11  Type Of Force      3460 non-null   object
#  12  Top Charge         142 non-null    object
#  13  SummonsCharge      51 non-null     object
#  14  Classification     711 non-null    object
# dtypes: object(15)
# memory usage: 405.6+ KB

# %%
df_first_half = pd.concat([df_q1, df_q2])

# %%
df_first_half
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...         Mitigated
# 1                                Abraham Lincoln HS(BS)           Summons
# 2                                Abraham Lincoln HS(BS)   Juvenile Report
# 3                                Abraham Lincoln HS(BS)          Arrested
# 4                                Abraham Lincoln HS(BS)         Mitigated
# ...                                                 ...               ...
# 3239                                        JHS 113(XE)   Juvenile Report
# 3240                           PS 142 Amalia Castro(MS)   Child in Crisis
# 3241                             EVANDER CHILDS HS(XE)    Juvenile Report
# 3242                                         IS 218(BN)          Arrested
# 3243  THE URBAN ASSEMBLY SCHOOL FOR MEDIA STUDIES(ML...          Arrested
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
df_second_half = pd.concat([df_q3, df_q4])

# %%
df_second_half
# Out:
#                                   School Campus Intervention Type  \
# 0                        Abraham Lincoln HS(BS)         Mitigated
# 1                        Abraham Lincoln HS(BS)         Mitigated
# 2                        Abraham Lincoln HS(BS)         Mitigated
# 3          Academy for Integrated Learning (BN)         Mitigated
# 4          Academy for Integrated Learning (BN)         Mitigated
# ...                                         ...               ...
# 3455                       WINGS ACADEMY(Bronx)           Summons
# 3456                       WINGS ACADEMY(Bronx)           Summons
# 3457                       WINGS ACADEMY(Bronx)           Summons
# 3458                       WINGS ACADEMY(Bronx)           Summons
# 3459  YALA MANHATTAN LEARNING CENTER(Manhattan)           Summons
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# 0              On-Site              No     Full-Time                 Y
# ...

# %%
df_second_half['Greater Than 21'] = df_second_half['Greater Than 21'].str.upper().str.title()

# %%
df_second_half
# Out:
#                                   School Campus Intervention Type  \
# 0                        Abraham Lincoln HS(BS)         Mitigated
# 1                        Abraham Lincoln HS(BS)         Mitigated
# 2                        Abraham Lincoln HS(BS)         Mitigated
# 3          Academy for Integrated Learning (BN)         Mitigated
# 4          Academy for Integrated Learning (BN)         Mitigated
# ...                                         ...               ...
# 3455                       WINGS ACADEMY(Bronx)           Summons
# 3456                       WINGS ACADEMY(Bronx)           Summons
# 3457                       WINGS ACADEMY(Bronx)           Summons
# 3458                       WINGS ACADEMY(Bronx)           Summons
# 3459  YALA MANHATTAN LEARNING CENTER(Manhattan)           Summons
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# 0              On-Site              No     Full-Time                 Y
# ...

# %%
SSA_2019_df = pd.concat([df_first_half, df_second_half])

# %%
SSA_2019_df
# Out:
#                                           School Campus Intervention Type  \
# 0     47 THE AMERICAN SIGN LANGUAGE & ENGLISH SECOND...         Mitigated
# 1                                Abraham Lincoln HS(BS)           Summons
# 2                                Abraham Lincoln HS(BS)   Juvenile Report
# 3                                Abraham Lincoln HS(BS)          Arrested
# 4                                Abraham Lincoln HS(BS)         Mitigated
# ...                                                 ...               ...
# 3455                               WINGS ACADEMY(Bronx)           Summons
# 3456                               WINGS ACADEMY(Bronx)           Summons
# 3457                               WINGS ACADEMY(Bronx)           Summons
# 3458                               WINGS ACADEMY(Bronx)           Summons
# 3459          YALA MANHATTAN LEARNING CENTER(Manhattan)           Summons
#
#      Incident Location Greater Than 21 Scanning Type Scanning Incident  \
# ...

# %%
SSA_2019_df.to_csv('data/clean_SSA_Report_School_2019.csv', encoding='utf-8')
